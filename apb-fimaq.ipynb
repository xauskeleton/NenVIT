# %%
# 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

# %%
# %ls -a
# Out:
# ./  ../  __notebook__.ipynb

# %%
# !git clone https://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@github.com/khaibui192/APB.git
# Out:
# Cloning into 'APB'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 46 (delta 19), reused 31 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (46/46), 2.71 MiB | 11.55 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %%
# %cd APB
# Out:
# /kaggle/working/APB

# %%
# !python apb_fimaq/run_cifar100.py \
    --batch-size 32 \
    --out-dir /kaggle/working/qat
# Out:
# ...
# RUN_CIFAR100 — APB QAT on CIFAR-100
# ...
# Configuration:
#   dataset                   = cifar100
#   data_dir                  =
#   apb_scope                 = skip
#   binary_ratio              = 0.75
#   epochs                    = 15
#   lr                        = 0.0001
#   batch_size                = 32
#   num_workers               = 4
#   seed                      = 3407
#   amp                       = True
#   out_dir                   = None
#   export_packed             = True
# ...
# Equivalent CLI:
#   python qat.py --dataset cifar100 --data-dir  --apb-scope skip --binary-ratio 0.75 --epochs 15 --lr 0.0001 --batch-size 32 --num-workers 4 --seed 3407 --amp --export-packed
# ...
#
#
# [2026-06-23 03:39:11] ===== run start (log → /kaggle/working/APB/checkpoints/qat/train.log) =====
# ...
# APB QAT on Swin-S | device=cuda
# ...

# %%
# !python apb_fimaq/run_cifar100.py --use-dplr-loss --dplr-lambda 3000 \
#     --batch-size 32 --out-dir /kaggle/working/qat
